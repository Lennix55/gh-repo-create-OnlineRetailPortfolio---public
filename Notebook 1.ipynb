# %%
df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("Files/raw/OnlineRetail.csv")
# Out:
# StatementMeta(, dc2cdbdb-cfb1-439e-8e79-8e43195445a0, 18, Finished, Available, Finished, False)

# %%
from pyspark.sql.functions import current_timestamp

df = df.withColumn("ingestion_timestamp", current_timestamp())
df = df.withColumnRenamed("Customer ID", "CustomerID")
# Out:
# StatementMeta(, dc2cdbdb-cfb1-439e-8e79-8e43195445a0, 19, Finished, Available, Finished, False)

# %%
df.write.mode("overwrite").saveAsTable("bronze_online_retail")
# Out:
# StatementMeta(, dc2cdbdb-cfb1-439e-8e79-8e43195445a0, 20, Finished, Available, Finished, False)

# %%
display(df)
# Out:
# StatementMeta(, dc2cdbdb-cfb1-439e-8e79-8e43195445a0, 21, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, dc39b4bc-d7d6-4877-b89a-4119fe833005)
